# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Mohamad Ali**
# Data Scientist

# %% [markdown]
# *I am interested in data science because I believe, as many also beleive, that data science has the power to improve the human condition by helping us investigate phenomena, acquire new knowledge and integrate previous knowledge with new ideas. I feel in love with data analysis and extracting the information behind it. I like being the "very important part" and the "trusted adviser" in making business decisions and recommendations that would improve business performance and increase profitability.*

# %% [markdown]
# ### My code in the next cell (cell 5) is suppose to calculate the average of numbers in a given list .

# %%
n=int(input("Enter the number of elements to be inserted: "))
a=[]
for i in range(0,n):
    elem=int(input("Enter element: "))
    a.append(elem)
avg=sum(a)/n
print("Average of elements in the list",round(avg,2))
# Out:
# Enter the number of elements to be inserted: 5
# Enter element: 3254564
# Enter element: 3215
# Enter element: 32
# Enter element: 321
# Enter element: 32
# Average of elements in the list 651632.8

# %% [markdown]
# **- Doors:**
# 1. Main Doors
# 2. Garage Doors
# 3. Room Doors
#
# **- Maintenance tools:**
# 1. Hammer
# 2. Screw drivers
# 3. Drill
#
# **- Paint:**
# 1. White
# 2. Brown
# 3. Green
# ************
#
# ~~Wrong~~
#
# > *"Nothing like doing your own homework"* - MA
